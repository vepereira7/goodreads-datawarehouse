# %%
import pandas as pd
import faker as fk

# %%
books = pd.read_csv('../CSV Files/books.csv')

# %%
books.head()
# Out:
#    book_id  goodreads_book_id  best_book_id  work_id  books_count       isbn  \
# 0        1            2767052       2767052  2792775          272  439023483
# 1        2                  3             3  4640799          491  439554934
# 2        3              41865         41865  3212258          226  316015849
# 3        4               2657          2657  3275794          487   61120081
# 4        5               4671          4671   245494         1356  743273567
#
#          isbn13  original_publication_year  \
# 0  9.780439e+12                     2008.0
# 1  9.780440e+12                     1997.0
# 2  9.780316e+12                     2005.0
# 3  9.780061e+12                     1960.0
# 4  9.780743e+12                     1925.0
#
#                              original_title  \
# 0                          The Hunger Games
# 1  Harry Potter and the Philosopher's Stone
# 2                                  Twilight
# 3                     To Kill a Mockingbird
# 4                          The Great Gatsby
#
#                                                title  ... ratings_count  \
# 0            The Hunger Games (The Hunger Games, #1)  ...       4780653
# 1  Harry Potter and the Sorcerer's Stone (Harry P...  ...       4602479
# 2                            Twilight (Twilight, #1)  ...       3866839
# 3                              To Kill a Mockingbird  ...       3198671
# 4                                   The Great Gatsby  ...       2683664
#
#    work_ratings_count  work_text_reviews_count  ratings_1  ratings_2  \
# 0             4942365                   155254      66715     127936
# 1             4800065                    75867      75504     101676
# 2             3916824                    95009     456191     436802
# 3             3340896                    72586      60427     117415
# 4             2773745                    51992      86236     197621
#
#    ratings_3  ratings_4  ratings_5  \
# 0     560092    1481305    2706317
# 1     455024    1156318    3011543
# 2     793319     875073    1355439
# 3     446835    1001952    1714267
# 4     606158     936012     947718
#
#                                            image_url  \
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1474154022m...
# 2  https://images.gr-assets.com/books/1361039443m...
# 3  https://images.gr-assets.com/books/1361975680m...
# 4  https://images.gr-assets.com/books/1490528560m...
#
#                                      small_image_url
# 0  https://images.gr-assets.com/books/1447303603s...
# 1  https://images.gr-assets.com/books/1474154022s...
# 2  https://images.gr-assets.com/books/1361039443s...
# 3  https://images.gr-assets.com/books/1361975680s...
# 4  https://images.gr-assets.com/books/1490528560s...
#
# [5 rows x 22 columns]

# %%
authorship = pd.read_csv('../CSV Files/authorship.csv')
authorship.head()
authorship = books[['book_id', 'authors']]
# Out:
#    book_id  authorship_id
# 0        1              1
# 1        2              2
# 2        2              2
# 3        3              3
# 4        4              4

# %%
authorship.head()
# Out:
#    book_id                      authors
# 0        1              Suzanne Collins
# 1        2  J.K. Rowling, Mary GrandPré
# 2        3              Stephenie Meyer
# 3        4                   Harper Lee
# 4        5          F. Scott Fitzgerald

# %%
authorship['authors'] = authorship['authors'].str.split(',')[0].strip()
# Out:
# c:\Users\iankk\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
authorship.head()
# Out:
#    book_id                         authors
# 0        1               [Suzanne Collins]
# 1        2  [J.K. Rowling,  Mary GrandPré]
# 2        3               [Stephenie Meyer]
# 3        4                    [Harper Lee]
# 4        5           [F. Scott Fitzgerald]

# %%
authorship['authorship_id'] = authorship.index+1
# Out:
# c:\Users\iankk\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
authorship
# Out:
#       book_id                         authors  authorship_id
# 0           1               [Suzanne Collins]              1
# 1           2  [J.K. Rowling,  Mary GrandPré]              2
# 2           3               [Stephenie Meyer]              3
# 3           4                    [Harper Lee]              4
# 4           5           [F. Scott Fitzgerald]              5
# ...       ...                             ...            ...
# 9995     9996                 [Ilona Andrews]           9996
# 9996     9997                [Robert A. Caro]           9997
# 9997     9998               [Patrick O'Brian]           9998
# 9998     9999               [Peggy Orenstein]           9999
# 9999    10000                   [John Keegan]          10000
#
# [10000 rows x 3 columns]

# %%
authors = authorship.explode('authors')

# %%
authors.drop(columns=['book_id','authorship_id'], inplace=True)

# %%
authors.drop_duplicates(inplace=True)

# %%
fake = fk.Faker()
authors['author_id'] = authors.index+1
authors['Adress'] = authors['authors'].apply(lambda x: fake.address())
authors['Sex'] = authors['authors'].apply(lambda x: fake.random_element(elements=('M', 'F')))
authors['email'] = authors['authors'].apply(lambda x: fake.email())
authors['phone'] = authors['authors'].apply(lambda x: fake.phone_number())

# %%
authors_id = authors[['author_id', 'authors']]

# %%
authorship = authorship.explode('authors')

# %%
authorship.merge(authors_id, on='authors', how='inner')
# Out:
#        book_id          authors  authorship_id  author_id
# 0            1  Suzanne Collins              1          1
# 1           17  Suzanne Collins             17          1
# 2           20  Suzanne Collins             20          1
# 3          507  Suzanne Collins            507          1
# 4         1531  Suzanne Collins           1531          1
# ...        ...              ...            ...        ...
# 13211     9991         Ben Okri           9991       9991
# 13212     9992   Miles  Cameron           9992       9992
# 13213     9993     Ian Mortimer           9993       9993
# 13214     9999  Peggy Orenstein           9999       9999
# 13215    10000      John Keegan          10000      10000
#
# [13216 rows x 4 columns]

# %%
authorship.drop(columns=['authors'], inplace=True)

# %%
authorship.to_csv('../CSV Files/authorship.csv', index=False)

# %%
authors = authors[['author_id','authors','Adress','Sex','email','phone']]

# %%
authors.rename(columns={'authors':'name'}, inplace=True)

# %%
authors.to_csv('../CSV Files/authors.csv', index=False)

# %%
books.drop(columns=['authors'], inplace=True)

# %%
books.to_csv('../CSV Files/books.csv', index=False)
